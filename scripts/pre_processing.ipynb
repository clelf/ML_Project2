# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helpers import *
# %load_ext autoreload
# %autoreload 2
# Additionally added libraries
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Load Data + take off the features of indexes in K vector
#here, take of only the record file name colomn = 1
K=[1]
[features_coarse,labels_coarse] = load_csv_data('data/train_data/features_coarse_segmentation.csv', 'data/train_data/labels_coarse_segmentation.csv', K)
[features_fine,labels_fine] = load_csv_data('data/train_data/features_fine_segmentation.csv', 'data/train_data/labels_fine_segmentation.csv', K)
[features_no,labels_no] = load_csv_data('data/train_data/features_no_segmentation.csv', 'data/train_data/labels_no_segmentation.csv', K)

# %%
df = analyse(features_coarse)
df
# Out:
#                        0          1          2   ...        69        70        71
# Statistics                                       ...
# Mean          1719.500000   6.620349   6.632267  ...  0.393169  0.300581  0.246802
# Variance    986133.250000   9.225051   9.313901  ...  0.202468  0.176221  0.151879
# Std            993.042421   3.037277   3.051868  ...  0.449964  0.419786  0.389717
# min              0.000000   0.000000   0.000000  ...  0.000000  0.000000  0.000000
# max           3439.000000  29.000000  30.000000  ...  1.000000  1.000000  1.000000
# n-NaNs           0.000000   0.000000   0.000000  ...  0.000000  0.000000  0.000000
# median        1719.500000   6.000000   6.000000  ...  0.000000  0.000000  0.000000
#
# [7 rows x 72 columns]

# %%
df = analyse(features_fine)
df
# Out:
#                       0          1          2   ...        69        70        71
# Statistics                                      ...
# Mean        3.504000e+03   4.351833   4.360964  ...  0.389357  0.293480  0.248966
# Variance    4.093840e+06   1.635095   1.609468  ...  0.204158  0.175747  0.155380
# Std         2.023324e+03   1.278708   1.268648  ...  0.451839  0.419222  0.394182
# min         0.000000e+00   1.000000   2.000000  ...  0.000000  0.000000  0.000000
# max         7.008000e+03  17.000000  16.000000  ...  1.000000  1.000000  1.000000
# n-NaNs      0.000000e+00   0.000000   0.000000  ...  0.000000  0.000000  0.000000
# median      3.504000e+03   4.000000   4.000000  ...  0.000000  0.000000  0.000000
#
# [7 rows x 72 columns]

# %%
df = analyse(features_no)
df
# Out:
#                        0           1           2   ...        70        71        72
# Statistics                                         ...
# Mean           829.000000   60.343580   60.408077  ...  0.389693  0.296564  0.251356
# Variance    229356.666667  285.705943  281.630339  ...  0.198200  0.171242  0.150804
# Std            478.911961   16.902838   16.781846  ...  0.445197  0.413814  0.388335
# min              0.000000   12.000000   12.000000  ...  0.000000  0.000000  0.000000
# max           1658.000000  106.000000  113.000000  ...  1.000000  1.000000  1.000000
# n-NaNs           0.000000    0.000000    0.000000  ...  0.000000  0.000000  0.000000
# median         829.000000   67.000000   67.000000  ...  0.000000  0.000000  0.000000
#
# [7 rows x 73 columns]

# %%
#Standardize
feat_details_coarse=standardize(features_coarse)
feat_details_fine=standardize(features_fine)
feat_details_no=standardize(features_no)
