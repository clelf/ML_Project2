# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helpers import *
# %load_ext autoreload
# %autoreload 2
# Additionally added libraries
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Load Data + take off the features of indexes in K vector
#here, take of only the record file name colomn = 1
K=[1]
[features_coarse,labels_coarse] = load_csv_data('../data/train_data/features_coarse_segmentation.csv', '../data/train_data/labels_coarse_segmentation.csv', K)
[features_fine,labels_fine] = load_csv_data('../data/train_data/features_fine_segmentation.csv', '../data/train_data/labels_fine_segmentation.csv', K)
[features_no,labels_no] = load_csv_data('../data/train_data/features_no_segmentation.csv', '../data/train_data/labels_no_segmentation.csv', K)

# %%
df, feat_details_coarse = analyse(features_coarse)
df
# Out:
#                        0          1          2          3          4   \
# Statistics
# Mean          1719.500000   6.620349   6.632267   6.685465   6.726453
# Variance    986133.250000   9.225051   9.313901   9.458626   9.429533
# Std            993.042421   3.037277   3.051868   3.075488   3.070754
# min              0.000000   0.000000   0.000000   0.000000   0.000000
# max           3439.000000  29.000000  30.000000  31.000000  29.000000
# n-NaNs           0.000000   0.000000   0.000000   0.000000   0.000000
# median        1719.500000   6.000000   6.000000   6.000000   6.000000
#
#                    5          6          7          8          9   ...  \
# Statistics                                                         ...
# Mean         6.750291   6.777035   6.810756   6.840116   6.884302  ...
# Variance     9.434448   9.606391   9.729594   9.790135   9.888358  ...
# Std          3.071555   3.099418   3.119230   3.128919   3.144576  ...
# ...

# %%
[df, feat_details_fine] = analyse(features_fine)
df
# Out:
#                       0          1          2          3          4   \
# Statistics
# Mean        3.504000e+03   4.351833   4.360964   4.412470   4.473962
# Variance    4.093840e+06   1.635095   1.609468   1.629127   1.636396
# Std         2.023324e+03   1.278708   1.268648   1.276373   1.279217
# min         0.000000e+00   1.000000   2.000000   1.000000   1.000000
# max         7.008000e+03  17.000000  16.000000  16.000000  19.000000
# n-NaNs      0.000000e+00   0.000000   0.000000   0.000000   0.000000
# median      3.504000e+03   4.000000   4.000000   4.000000   4.000000
#
#                    5          6          7          8          9   ...  \
# Statistics                                                         ...
# Mean         4.503781   4.521758   4.554002   4.593523   4.609645  ...
# Variance     1.698409   1.659428   1.760281   1.804387   1.800540  ...
# Std          1.303230   1.288188   1.326756   1.343275   1.341842  ...
# ...

# %%
[df, feat_details_no] = analyse(features_no)
df
# Out:
#                        0           1           2           3           4   \
# Statistics
# Mean           829.000000   60.343580   60.408077   60.696203   60.792646
# Variance    229356.666667  285.705943  281.630339  284.520124  280.680332
# Std            478.911961   16.902838   16.781846   16.867724   16.753517
# min              0.000000   12.000000   12.000000   12.000000   13.000000
# max           1658.000000  106.000000  113.000000  111.000000   95.000000
# n-NaNs           0.000000    0.000000    0.000000    0.000000    0.000000
# median         829.000000   67.000000   67.000000   67.000000   68.000000
#
#                     5           6           7           8           9   ...  \
# Statistics                                                              ...
# Mean         60.872212   60.962628   61.091621   61.164557   61.231465  ...
# Variance    279.441175  279.392214  283.053691  279.608243  282.234549  ...
# ...

# %%
#Standardize
feat_details_coarse=standardize(features_coarse, feat_details_coarse)
feat_details_fine=standardize(features_fine, feat_details_fine)
feat_details_no=standardize(features_no, feat_details_no)
